# %% [markdown]
# <a href="https://colab.research.google.com/github/UrviSoni/pytorch_deeplearning/blob/master/filter_edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -c https://upload.wikimedia.org/wikipedia/commons/1/16/Lights-clouds-dark-car_%2823698576464%29.jpg
# Out:
# --2018-12-28 17:06:56--  https://upload.wikimedia.org/wikipedia/commons/1/16/Lights-clouds-dark-car_%2823698576464%29.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3743727 (3.6M) [image/jpeg]
# Saving to: ‘Lights-clouds-dark-car_(23698576464).jpg’
#
# Lights-clouds-dark- 100%[===================>]   3.57M  21.5MB/s    in 0.2s
#
# 2018-12-28 17:06:56 (21.5 MB/s) - ‘Lights-clouds-dark-car_(23698576464).jpg’ saved [3743727/3743727]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %%
# %matplotlib inline
# !ls -l
# Out:
# total 3664
# -rw-r--r-- 1 root root 3743727 Sep 16  2016 'Lights-clouds-dark-car_(23698576464).jpg'
# drwxr-xr-x 1 root root    4096 Dec 18 20:29  sample_data

# %%
# Read in the image
image = mpimg.imread('Lights-clouds-dark-car_(23698576464).jpg')
plt.grid(False)
plt.imshow(image)

# %%
# Convert to grayscale for filtering
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.grid(False)
plt.imshow(gray, cmap='gray')

# %%
# Create a custom kernel

# 3x3 array for edge detection
sobel_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])

## TODO: Create and apply a Sobel x operator
sobel_x = sobel_y.transpose()

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_x)
plt.grid(False)

plt.imshow(filtered_image, cmap='gray')
